# %%
import pandas as pd
import numpy as np
from keras import models, layers
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.preprocessing.text import Tokenizer
from sklearn.model_selection import train_test_split
from keras import metrics
from keras.models import load_model
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("darkgrid")

# %%
df = pd.read_csv('data/french_open_with_feature.csv')

df = df.dropna()

df['diff_rank'] = df['player_0_rank'] - df['player_1_rank']

# %%
features_list = [
 'diff_rank',
 'diff_match_win_percent',
 'diff_games_win_percent',
 'diff_5_set_match_win_percent',
 'diff_close_sets_percent',
 'diff_match_win_percent_clay',
 'diff_games_win_percent_clay',
 'diff_5_set_match_win_percent_clay',
 'diff_close_sets_percent_clay',
 'diff_match_win_percent_52',
 'diff_games_win_percent_52',
 'diff_5_set_match_win_percent_52',
 'diff_close_sets_percent_52',
 'diff_match_win_percent_clay_60',
 'diff_games_win_percent_clay_60',
 'diff_5_set_match_win_percent_clay_60',
 'diff_close_sets_percent_clay_60',
 'diff_match_win_percent_hh',
 'diff_games_win_percent_hh',
 'diff_match_win_percent_clay_hh',
 'diff_games_win_percent_clay_hh']

# %%
target = df.outcome
features = df[features_list]

train_features, test_features, train_target, test_target = train_test_split(features, target, test_size=0.30, random_state=1)

# %%
network = models.Sequential()
network.add(layers.Dense(units=64, activation='relu', input_shape=(len(features.columns),)))
network.add(layers.Dense(units=32, activation='relu'))
network.add(layers.Dense(units=1, activation='sigmoid'))

network.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy']) 

es = EarlyStopping(monitor='val_loss', mode='min', verbose=0, patience=500)
mc = ModelCheckpoint('data/best_model.h5', monitor='val_loss', mode='min', verbose=2, save_best_only=True)

history = network.fit(train_features, train_target, 
            epochs=1000, verbose=0, batch_size=128, 
            validation_data=(test_features, test_target), callbacks=[es, mc]) 

saved_model = load_model('data/best_model.h5')
# Out:
# Epoch 00001: val_loss improved from inf to 0.92859, saving model to data\best_model.h5
#
# Epoch 00002: val_loss did not improve from 0.92859
#
# Epoch 00003: val_loss improved from 0.92859 to 0.60282, saving model to data\best_model.h5
#
# Epoch 00004: val_loss did not improve from 0.60282
#
# Epoch 00005: val_loss improved from 0.60282 to 0.57079, saving model to data\best_model.h5
#
# Epoch 00006: val_loss improved from 0.57079 to 0.56798, saving model to data\best_model.h5
#
# Epoch 00007: val_loss improved from 0.56798 to 0.56138, saving model to data\best_model.h5
#
# Epoch 00008: val_loss improved from 0.56138 to 0.55632, saving model to data\best_model.h5
#
# Epoch 00009: val_loss improved from 0.55632 to 0.55289, saving model to data\best_model.h5
#
# Epoch 00010: val_loss did not improve from 0.55289
#
# Epoch 00011: val_loss improved from 0.55289 to 0.55268, saving model to data\best_model.h5
#
# Epoch 00012: val_loss improved from 0.55268 to 0.55019, saving model to data\best_model.h5
#
# Epoch 00013: val_loss improved from 0.55019 to 0.54325, saving model to data\best_model.h5
#
# Epoch 00014: val_loss did not improve from 0.54325
#
# Epoch 00015: val_loss did not improve from 0.54325
#
# Epoch 00016: val_loss did not improve from 0.54325
#
# Epoch 00017: val_loss improved from 0.54325 to 0.53735, saving model to data\best_model.h5
#
# Epoch 00018: val_loss improved from 0.53735 to 0.53727, saving model to data\best_model.h5
#
# Epoch 00019: val_loss did not improve from 0.53727
#
# Epoch 00020: val_loss did not improve from 0.53727
#
# Epoch 00021: val_loss did not improve from 0.53727
#
# Epoch 00022: val_loss did not improve from 0.53727
#
# Epoch 00023: val_loss improved from 0.53727 to 0.53509, saving model to data\best_model.h5
#
# Epoch 00024: val_loss did not improve from 0.53509
#
# Epoch 00025: val_loss did not improve from 0.53509
#
# Epoch 00026: val_loss did not improve from 0.53509
#
# Epoch 00027: val_loss did not improve from 0.53509
#
# Epoch 00028: val_loss did not improve from 0.53509
#
# Epoch 00029: val_loss improved from 0.53509 to 0.53327, saving model to data\best_model.h5
#
# Epoch 00030: val_loss did not improve from 0.53327
#
# Epoch 00031: val_loss did not improve from 0.53327
#
# Epoch 00032: val_loss improved from 0.53327 to 0.53321, saving model to data\best_model.h5
#
# Epoch 00033: val_loss did not improve from 0.53321
#
# Epoch 00034: val_loss did not improve from 0.53321
#
# Epoch 00035: val_loss did not improve from 0.53321
#
# Epoch 00036: val_loss did not improve from 0.53321
#
# Epoch 00037: val_loss did not improve from 0.53321
#
# Epoch 00038: val_loss did not improve from 0.53321
#
# Epoch 00039: val_loss did not improve from 0.53321
#
# Epoch 00040: val_loss did not improve from 0.53321
#
# Epoch 00041: val_loss did not improve from 0.53321
#
# Epoch 00042: val_loss did not improve from 0.53321
#
# Epoch 00043: val_loss did not improve from 0.53321
#
# Epoch 00044: val_loss did not improve from 0.53321
#
# Epoch 00045: val_loss did not improve from 0.53321
#
# Epoch 00046: val_loss did not improve from 0.53321
#
# Epoch 00047: val_loss did not improve from 0.53321
#
# Epoch 00048: val_loss did not improve from 0.53321
#
# Epoch 00049: val_loss did not improve from 0.53321
#
# Epoch 00050: val_loss did not improve from 0.53321
#
# Epoch 00051: val_loss did not improve from 0.53321
#
# Epoch 00052: val_loss did not improve from 0.53321
#
# Epoch 00053: val_loss did not improve from 0.53321
#
# Epoch 00054: val_loss did not improve from 0.53321
#
# Epoch 00055: val_loss did not improve from 0.53321
#
# Epoch 00056: val_loss did not improve from 0.53321
#
# Epoch 00057: val_loss did not improve from 0.53321
#
# Epoch 00058: val_loss did not improve from 0.53321
#
# Epoch 00059: val_loss did not improve from 0.53321
#
# Epoch 00060: val_loss did not improve from 0.53321
#
# Epoch 00061: val_loss did not improve from 0.53321
#
# Epoch 00062: val_loss did not improve from 0.53321
#
# Epoch 00063: val_loss did not improve from 0.53321
#
# Epoch 00064: val_loss did not improve from 0.53321
#
# Epoch 00065: val_loss did not improve from 0.53321
#
# Epoch 00066: val_loss did not improve from 0.53321
#
# Epoch 00067: val_loss did not improve from 0.53321
#
# Epoch 00068: val_loss did not improve from 0.53321
#
# Epoch 00069: val_loss did not improve from 0.53321
#
# Epoch 00070: val_loss did not improve from 0.53321
#
# Epoch 00071: val_loss did not improve from 0.53321
#
# Epoch 00072: val_loss did not improve from 0.53321
#
# Epoch 00073: val_loss did not improve from 0.53321
#
# Epoch 00074: val_loss did not improve from 0.53321
#
# Epoch 00075: val_loss did not improve from 0.53321
#
# Epoch 00076: val_loss did not improve from 0.53321
#
# Epoch 00077: val_loss did not improve from 0.53321
#
# Epoch 00078: val_loss did not improve from 0.53321
#
# Epoch 00079: val_loss did not improve from 0.53321
#
# Epoch 00080: val_loss did not improve from 0.53321
#
# Epoch 00081: val_loss did not improve from 0.53321
#
# Epoch 00082: val_loss did not improve from 0.53321
#
# Epoch 00083: val_loss did not improve from 0.53321
#
# Epoch 00084: val_loss did not improve from 0.53321
#
# Epoch 00085: val_loss did not improve from 0.53321
#
# Epoch 00086: val_loss did not improve from 0.53321
#
# Epoch 00087: val_loss did not improve from 0.53321
#
# Epoch 00088: val_loss did not improve from 0.53321
#
# Epoch 00089: val_loss did not improve from 0.53321
#
# Epoch 00090: val_loss did not improve from 0.53321
#
# Epoch 00091: val_loss did not improve from 0.53321
#
# Epoch 00092: val_loss did not improve from 0.53321
#
# Epoch 00093: val_loss did not improve from 0.53321
#
# Epoch 00094: val_loss did not improve from 0.53321
#
# Epoch 00095: val_loss did not improve from 0.53321
#
# Epoch 00096: val_loss did not improve from 0.53321
#
# Epoch 00097: val_loss did not improve from 0.53321
#
# Epoch 00098: val_loss did not improve from 0.53321
#
# Epoch 00099: val_loss did not improve from 0.53321
#
# Epoch 00100: val_loss did not improve from 0.53321
#
# Epoch 00101: val_loss did not improve from 0.53321
#
# Epoch 00102: val_loss did not improve from 0.53321
#
# Epoch 00103: val_loss did not improve from 0.53321
#
# Epoch 00104: val_loss did not improve from 0.53321
#
# Epoch 00105: val_loss did not improve from 0.53321
#
# Epoch 00106: val_loss did not improve from 0.53321
#
# Epoch 00107: val_loss did not improve from 0.53321
#
# Epoch 00108: val_loss did not improve from 0.53321
#
# Epoch 00109: val_loss did not improve from 0.53321
#
# Epoch 00110: val_loss did not improve from 0.53321
#
# Epoch 00111: val_loss did not improve from 0.53321
#
# Epoch 00112: val_loss did not improve from 0.53321
#
# Epoch 00113: val_loss did not improve from 0.53321
#
# Epoch 00114: val_loss did not improve from 0.53321
#
# Epoch 00115: val_loss did not improve from 0.53321
#
# Epoch 00116: val_loss did not improve from 0.53321
#
# Epoch 00117: val_loss did not improve from 0.53321
#
# Epoch 00118: val_loss did not improve from 0.53321
#
# Epoch 00119: val_loss did not improve from 0.53321
#
# Epoch 00120: val_loss did not improve from 0.53321
#
# Epoch 00121: val_loss did not improve from 0.53321
#
# Epoch 00122: val_loss did not improve from 0.53321
#
# Epoch 00123: val_loss did not improve from 0.53321
#
# Epoch 00124: val_loss did not improve from 0.53321
#
# Epoch 00125: val_loss did not improve from 0.53321
#
# Epoch 00126: val_loss did not improve from 0.53321
#
# Epoch 00127: val_loss did not improve from 0.53321
#
# Epoch 00128: val_loss did not improve from 0.53321
#
# Epoch 00129: val_loss did not improve from 0.53321
#
# Epoch 00130: val_loss did not improve from 0.53321
#
# Epoch 00131: val_loss did not improve from 0.53321
#
# Epoch 00132: val_loss did not improve from 0.53321
#
# Epoch 00133: val_loss did not improve from 0.53321
#
# Epoch 00134: val_loss did not improve from 0.53321
#
# Epoch 00135: val_loss did not improve from 0.53321
#
# Epoch 00136: val_loss did not improve from 0.53321
#
# Epoch 00137: val_loss did not improve from 0.53321
#
# Epoch 00138: val_loss did not improve from 0.53321
#
# Epoch 00139: val_loss did not improve from 0.53321
#
# Epoch 00140: val_loss did not improve from 0.53321
#
# Epoch 00141: val_loss did not improve from 0.53321
#
# Epoch 00142: val_loss did not improve from 0.53321
#
# Epoch 00143: val_loss did not improve from 0.53321
#
# Epoch 00144: val_loss did not improve from 0.53321
#
# Epoch 00145: val_loss did not improve from 0.53321
#
# Epoch 00146: val_loss did not improve from 0.53321
#
# Epoch 00147: val_loss did not improve from 0.53321
#
# Epoch 00148: val_loss did not improve from 0.53321
#
# Epoch 00149: val_loss did not improve from 0.53321
# Epoch 00150: val_loss did not improve from 0.53321
#
# Epoch 00151: val_loss did not improve from 0.53321
#
# Epoch 00152: val_loss did not improve from 0.53321
#
# Epoch 00153: val_loss did not improve from 0.53321
#
# Epoch 00154: val_loss did not improve from 0.53321
#
# Epoch 00155: val_loss did not improve from 0.53321
#
# Epoch 00156: val_loss did not improve from 0.53321
#
# Epoch 00157: val_loss did not improve from 0.53321
#
# Epoch 00158: val_loss did not improve from 0.53321
#
# Epoch 00159: val_loss did not improve from 0.53321
#
# Epoch 00160: val_loss did not improve from 0.53321
#
# Epoch 00161: val_loss did not improve from 0.53321
#
# Epoch 00162: val_loss did not improve from 0.53321
#
# Epoch 00163: val_loss did not improve from 0.53321
#
# Epoch 00164: val_loss did not improve from 0.53321
#
# Epoch 00165: val_loss did not improve from 0.53321
#
# Epoch 00166: val_loss did not improve from 0.53321
#
# Epoch 00167: val_loss did not improve from 0.53321
#
# Epoch 00168: val_loss did not improve from 0.53321
#
# Epoch 00169: val_loss did not improve from 0.53321
#
# Epoch 00170: val_loss did not improve from 0.53321
#
# Epoch 00171: val_loss did not improve from 0.53321
#
# Epoch 00172: val_loss did not improve from 0.53321
#
# Epoch 00173: val_loss did not improve from 0.53321
#
# Epoch 00174: val_loss did not improve from 0.53321
#
# Epoch 00175: val_loss did not improve from 0.53321
#
# Epoch 00176: val_loss did not improve from 0.53321
#
# Epoch 00177: val_loss did not improve from 0.53321
#
# Epoch 00178: val_loss did not improve from 0.53321
#
# Epoch 00179: val_loss did not improve from 0.53321
#
# Epoch 00180: val_loss did not improve from 0.53321
#
# Epoch 00181: val_loss did not improve from 0.53321
#
# Epoch 00182: val_loss did not improve from 0.53321
#
# Epoch 00183: val_loss did not improve from 0.53321
#
# Epoch 00184: val_loss did not improve from 0.53321
#
# Epoch 00185: val_loss did not improve from 0.53321
#
# Epoch 00186: val_loss did not improve from 0.53321
#
# Epoch 00187: val_loss did not improve from 0.53321
#
# Epoch 00188: val_loss did not improve from 0.53321
#
# Epoch 00189: val_loss did not improve from 0.53321
#
# Epoch 00190: val_loss did not improve from 0.53321
#
# Epoch 00191: val_loss did not improve from 0.53321
#
# Epoch 00192: val_loss did not improve from 0.53321
#
# Epoch 00193: val_loss did not improve from 0.53321
#
# Epoch 00194: val_loss did not improve from 0.53321
#
# Epoch 00195: val_loss did not improve from 0.53321
#
# Epoch 00196: val_loss did not improve from 0.53321
#
# Epoch 00197: val_loss did not improve from 0.53321
#
# Epoch 00198: val_loss did not improve from 0.53321
#
# Epoch 00199: val_loss did not improve from 0.53321
#
# Epoch 00200: val_loss did not improve from 0.53321
#
# Epoch 00201: val_loss did not improve from 0.53321
#
# Epoch 00202: val_loss did not improve from 0.53321
#
# Epoch 00203: val_loss did not improve from 0.53321
#
# Epoch 00204: val_loss did not improve from 0.53321
#
# Epoch 00205: val_loss did not improve from 0.53321
#
# Epoch 00206: val_loss did not improve from 0.53321
#
# Epoch 00207: val_loss did not improve from 0.53321
#
# Epoch 00208: val_loss did not improve from 0.53321
#
# Epoch 00209: val_loss did not improve from 0.53321
#
# Epoch 00210: val_loss did not improve from 0.53321
#
# Epoch 00211: val_loss did not improve from 0.53321
#
# Epoch 00212: val_loss did not improve from 0.53321
#
# Epoch 00213: val_loss did not improve from 0.53321
#
# Epoch 00214: val_loss did not improve from 0.53321
#
# Epoch 00215: val_loss did not improve from 0.53321
#
# Epoch 00216: val_loss did not improve from 0.53321
#
# Epoch 00217: val_loss did not improve from 0.53321
#
# Epoch 00218: val_loss did not improve from 0.53321
#
# Epoch 00219: val_loss did not improve from 0.53321
#
# Epoch 00220: val_loss did not improve from 0.53321
#
# Epoch 00221: val_loss did not improve from 0.53321
#
# Epoch 00222: val_loss did not improve from 0.53321
#
# Epoch 00223: val_loss did not improve from 0.53321
#
# Epoch 00224: val_loss did not improve from 0.53321
#
# Epoch 00225: val_loss did not improve from 0.53321
#
# Epoch 00226: val_loss did not improve from 0.53321
#
# Epoch 00227: val_loss did not improve from 0.53321
#
# Epoch 00228: val_loss did not improve from 0.53321
#
# Epoch 00229: val_loss did not improve from 0.53321
#
# Epoch 00230: val_loss did not improve from 0.53321
#
# Epoch 00231: val_loss did not improve from 0.53321
#
# Epoch 00232: val_loss did not improve from 0.53321
#
# Epoch 00233: val_loss did not improve from 0.53321
#
# Epoch 00234: val_loss did not improve from 0.53321
#
# Epoch 00235: val_loss did not improve from 0.53321
#
# Epoch 00236: val_loss did not improve from 0.53321
#
# Epoch 00237: val_loss did not improve from 0.53321
#
# Epoch 00238: val_loss did not improve from 0.53321
#
# Epoch 00239: val_loss did not improve from 0.53321
#
# Epoch 00240: val_loss did not improve from 0.53321
#
# Epoch 00241: val_loss did not improve from 0.53321
#
# Epoch 00242: val_loss did not improve from 0.53321
#
# Epoch 00243: val_loss did not improve from 0.53321
#
# Epoch 00244: val_loss did not improve from 0.53321
#
# Epoch 00245: val_loss did not improve from 0.53321
#
# Epoch 00246: val_loss did not improve from 0.53321
#
# Epoch 00247: val_loss did not improve from 0.53321
#
# Epoch 00248: val_loss did not improve from 0.53321
#
# Epoch 00249: val_loss did not improve from 0.53321
#
# Epoch 00250: val_loss did not improve from 0.53321
#
# Epoch 00251: val_loss did not improve from 0.53321
#
# Epoch 00252: val_loss did not improve from 0.53321
#
# Epoch 00253: val_loss did not improve from 0.53321
#
# Epoch 00254: val_loss did not improve from 0.53321
#
# Epoch 00255: val_loss did not improve from 0.53321
#
# Epoch 00256: val_loss did not improve from 0.53321
#
# Epoch 00257: val_loss did not improve from 0.53321
#
# Epoch 00258: val_loss did not improve from 0.53321
#
# Epoch 00259: val_loss did not improve from 0.53321
#
# Epoch 00260: val_loss did not improve from 0.53321
#
# Epoch 00261: val_loss did not improve from 0.53321
#
# Epoch 00262: val_loss did not improve from 0.53321
#
# Epoch 00263: val_loss did not improve from 0.53321
#
# Epoch 00264: val_loss did not improve from 0.53321
#
# Epoch 00265: val_loss did not improve from 0.53321
#
# Epoch 00266: val_loss did not improve from 0.53321
#
# Epoch 00267: val_loss did not improve from 0.53321
#
# Epoch 00268: val_loss did not improve from 0.53321
#
# Epoch 00269: val_loss did not improve from 0.53321
#
# Epoch 00270: val_loss did not improve from 0.53321
#
# Epoch 00271: val_loss did not improve from 0.53321
#
# Epoch 00272: val_loss did not improve from 0.53321
#
# Epoch 00273: val_loss did not improve from 0.53321
#
# Epoch 00274: val_loss did not improve from 0.53321
#
# Epoch 00275: val_loss did not improve from 0.53321
#
# Epoch 00276: val_loss did not improve from 0.53321
#
# Epoch 00277: val_loss did not improve from 0.53321
#
# Epoch 00278: val_loss did not improve from 0.53321
#
# Epoch 00279: val_loss did not improve from 0.53321
#
# Epoch 00280: val_loss did not improve from 0.53321
#
# Epoch 00281: val_loss did not improve from 0.53321
#
# Epoch 00282: val_loss did not improve from 0.53321
#
# Epoch 00283: val_loss did not improve from 0.53321
#
# Epoch 00284: val_loss did not improve from 0.53321
#
# Epoch 00285: val_loss did not improve from 0.53321
#
# Epoch 00286: val_loss did not improve from 0.53321
#
# Epoch 00287: val_loss did not improve from 0.53321
#
# Epoch 00288: val_loss did not improve from 0.53321
#
# Epoch 00289: val_loss did not improve from 0.53321
#
# Epoch 00290: val_loss did not improve from 0.53321
#
# Epoch 00291: val_loss did not improve from 0.53321
#
# Epoch 00292: val_loss did not improve from 0.53321
#
# Epoch 00293: val_loss did not improve from 0.53321
#
# Epoch 00294: val_loss did not improve from 0.53321
#
# Epoch 00295: val_loss did not improve from 0.53321
#
# Epoch 00296: val_loss did not improve from 0.53321
#
# Epoch 00297: val_loss did not improve from 0.53321
#
# Epoch 00298: val_loss did not improve from 0.53321
#
# Epoch 00299: val_loss did not improve from 0.53321
#
# Epoch 00300: val_loss did not improve from 0.53321
#
# Epoch 00301: val_loss did not improve from 0.53321
#
# Epoch 00302: val_loss did not improve from 0.53321
#
# Epoch 00303: val_loss did not improve from 0.53321
#
# Epoch 00304: val_loss did not improve from 0.53321
#
# Epoch 00305: val_loss did not improve from 0.53321
#
# Epoch 00306: val_loss did not improve from 0.53321
#
# Epoch 00307: val_loss did not improve from 0.53321
# Epoch 00308: val_loss did not improve from 0.53321
#
# Epoch 00309: val_loss did not improve from 0.53321
#
# Epoch 00310: val_loss did not improve from 0.53321
#
# Epoch 00311: val_loss did not improve from 0.53321
#
# Epoch 00312: val_loss did not improve from 0.53321
#
# Epoch 00313: val_loss did not improve from 0.53321
#
# Epoch 00314: val_loss did not improve from 0.53321
#
# Epoch 00315: val_loss did not improve from 0.53321
#
# Epoch 00316: val_loss did not improve from 0.53321
#
# Epoch 00317: val_loss did not improve from 0.53321
#
# Epoch 00318: val_loss did not improve from 0.53321
#
# Epoch 00319: val_loss did not improve from 0.53321
#
# Epoch 00320: val_loss did not improve from 0.53321
#
# Epoch 00321: val_loss did not improve from 0.53321
#
# Epoch 00322: val_loss did not improve from 0.53321
#
# Epoch 00323: val_loss did not improve from 0.53321
#
# Epoch 00324: val_loss did not improve from 0.53321
#
# Epoch 00325: val_loss did not improve from 0.53321
#
# Epoch 00326: val_loss did not improve from 0.53321
#
# Epoch 00327: val_loss did not improve from 0.53321
#
# Epoch 00328: val_loss did not improve from 0.53321
#
# Epoch 00329: val_loss did not improve from 0.53321
#
# Epoch 00330: val_loss did not improve from 0.53321
#
# Epoch 00331: val_loss did not improve from 0.53321
#
# Epoch 00332: val_loss did not improve from 0.53321
#
# Epoch 00333: val_loss did not improve from 0.53321
#
# Epoch 00334: val_loss did not improve from 0.53321
#
# Epoch 00335: val_loss did not improve from 0.53321
#
# Epoch 00336: val_loss did not improve from 0.53321
#
# Epoch 00337: val_loss did not improve from 0.53321
#
# Epoch 00338: val_loss did not improve from 0.53321
#
# Epoch 00339: val_loss did not improve from 0.53321
#
# Epoch 00340: val_loss did not improve from 0.53321
#
# Epoch 00341: val_loss did not improve from 0.53321
#
# Epoch 00342: val_loss did not improve from 0.53321
#
# Epoch 00343: val_loss did not improve from 0.53321
#
# Epoch 00344: val_loss did not improve from 0.53321
#
# Epoch 00345: val_loss did not improve from 0.53321
#
# Epoch 00346: val_loss did not improve from 0.53321
#
# Epoch 00347: val_loss did not improve from 0.53321
#
# Epoch 00348: val_loss did not improve from 0.53321
#
# Epoch 00349: val_loss did not improve from 0.53321
#
# Epoch 00350: val_loss did not improve from 0.53321
#
# Epoch 00351: val_loss did not improve from 0.53321
#
# Epoch 00352: val_loss did not improve from 0.53321
#
# Epoch 00353: val_loss did not improve from 0.53321
#
# Epoch 00354: val_loss did not improve from 0.53321
#
# Epoch 00355: val_loss did not improve from 0.53321
#
# Epoch 00356: val_loss did not improve from 0.53321
#
# Epoch 00357: val_loss did not improve from 0.53321
#
# Epoch 00358: val_loss did not improve from 0.53321
#
# Epoch 00359: val_loss did not improve from 0.53321
#
# Epoch 00360: val_loss did not improve from 0.53321
#
# Epoch 00361: val_loss did not improve from 0.53321
#
# Epoch 00362: val_loss did not improve from 0.53321
#
# Epoch 00363: val_loss did not improve from 0.53321
#
# Epoch 00364: val_loss did not improve from 0.53321
#
# Epoch 00365: val_loss did not improve from 0.53321
#
# Epoch 00366: val_loss did not improve from 0.53321
#
# Epoch 00367: val_loss did not improve from 0.53321
#
# Epoch 00368: val_loss did not improve from 0.53321
#
# Epoch 00369: val_loss did not improve from 0.53321
#
# Epoch 00370: val_loss did not improve from 0.53321
#
# Epoch 00371: val_loss did not improve from 0.53321
#
# Epoch 00372: val_loss did not improve from 0.53321
#
# Epoch 00373: val_loss did not improve from 0.53321
#
# Epoch 00374: val_loss did not improve from 0.53321
#
# Epoch 00375: val_loss did not improve from 0.53321
#
# Epoch 00376: val_loss did not improve from 0.53321
#
# Epoch 00377: val_loss did not improve from 0.53321
#
# Epoch 00378: val_loss did not improve from 0.53321
#
# Epoch 00379: val_loss did not improve from 0.53321
#
# Epoch 00380: val_loss did not improve from 0.53321
#
# Epoch 00381: val_loss did not improve from 0.53321
#
# Epoch 00382: val_loss did not improve from 0.53321
#
# Epoch 00383: val_loss did not improve from 0.53321
#
# Epoch 00384: val_loss did not improve from 0.53321
#
# Epoch 00385: val_loss did not improve from 0.53321
#
# Epoch 00386: val_loss did not improve from 0.53321
#
# Epoch 00387: val_loss did not improve from 0.53321
#
# Epoch 00388: val_loss did not improve from 0.53321
#
# Epoch 00389: val_loss did not improve from 0.53321
#
# Epoch 00390: val_loss did not improve from 0.53321
#
# Epoch 00391: val_loss did not improve from 0.53321
#
# Epoch 00392: val_loss did not improve from 0.53321
#
# Epoch 00393: val_loss did not improve from 0.53321
#
# Epoch 00394: val_loss did not improve from 0.53321
#
# Epoch 00395: val_loss did not improve from 0.53321
#
# Epoch 00396: val_loss did not improve from 0.53321
#
# Epoch 00397: val_loss did not improve from 0.53321
#
# Epoch 00398: val_loss did not improve from 0.53321
#
# Epoch 00399: val_loss did not improve from 0.53321
#
# Epoch 00400: val_loss did not improve from 0.53321
#
# Epoch 00401: val_loss did not improve from 0.53321
#
# Epoch 00402: val_loss did not improve from 0.53321
#
# Epoch 00403: val_loss did not improve from 0.53321
#
# Epoch 00404: val_loss did not improve from 0.53321
#
# Epoch 00405: val_loss did not improve from 0.53321
#
# Epoch 00406: val_loss did not improve from 0.53321
#
# Epoch 00407: val_loss did not improve from 0.53321
#
# Epoch 00408: val_loss did not improve from 0.53321
#
# Epoch 00409: val_loss did not improve from 0.53321
#
# Epoch 00410: val_loss did not improve from 0.53321
#
# Epoch 00411: val_loss did not improve from 0.53321
#
# Epoch 00412: val_loss did not improve from 0.53321
#
# Epoch 00413: val_loss did not improve from 0.53321
#
# Epoch 00414: val_loss did not improve from 0.53321
#
# Epoch 00415: val_loss did not improve from 0.53321
#
# Epoch 00416: val_loss did not improve from 0.53321
#
# Epoch 00417: val_loss did not improve from 0.53321
#
# Epoch 00418: val_loss did not improve from 0.53321
#
# Epoch 00419: val_loss did not improve from 0.53321
#
# Epoch 00420: val_loss did not improve from 0.53321
#
# Epoch 00421: val_loss did not improve from 0.53321
#
# Epoch 00422: val_loss did not improve from 0.53321
#
# Epoch 00423: val_loss did not improve from 0.53321
#
# Epoch 00424: val_loss did not improve from 0.53321
#
# Epoch 00425: val_loss did not improve from 0.53321
#
# Epoch 00426: val_loss did not improve from 0.53321
#
# Epoch 00427: val_loss did not improve from 0.53321
#
# Epoch 00428: val_loss did not improve from 0.53321
#
# Epoch 00429: val_loss did not improve from 0.53321
#
# Epoch 00430: val_loss did not improve from 0.53321
#
# Epoch 00431: val_loss did not improve from 0.53321
#
# Epoch 00432: val_loss did not improve from 0.53321
#
# Epoch 00433: val_loss did not improve from 0.53321
#
# Epoch 00434: val_loss did not improve from 0.53321
#
# Epoch 00435: val_loss did not improve from 0.53321
#
# Epoch 00436: val_loss did not improve from 0.53321
#
# Epoch 00437: val_loss did not improve from 0.53321
#
# Epoch 00438: val_loss did not improve from 0.53321
#
# Epoch 00439: val_loss did not improve from 0.53321
#
# Epoch 00440: val_loss did not improve from 0.53321
#
# Epoch 00441: val_loss did not improve from 0.53321
#
# Epoch 00442: val_loss did not improve from 0.53321
#
# Epoch 00443: val_loss did not improve from 0.53321
#
# Epoch 00444: val_loss did not improve from 0.53321
#
# Epoch 00445: val_loss did not improve from 0.53321
#
# Epoch 00446: val_loss did not improve from 0.53321
#
# Epoch 00447: val_loss did not improve from 0.53321
#
# Epoch 00448: val_loss did not improve from 0.53321
#
# Epoch 00449: val_loss did not improve from 0.53321
#
# Epoch 00450: val_loss did not improve from 0.53321
#
# Epoch 00451: val_loss did not improve from 0.53321
#
# Epoch 00452: val_loss did not improve from 0.53321
#
# Epoch 00453: val_loss did not improve from 0.53321
#
# Epoch 00454: val_loss did not improve from 0.53321
#
# Epoch 00455: val_loss did not improve from 0.53321
#
# Epoch 00456: val_loss did not improve from 0.53321
#
# Epoch 00457: val_loss did not improve from 0.53321
#
# Epoch 00458: val_loss did not improve from 0.53321
#
# Epoch 00459: val_loss did not improve from 0.53321
#
# Epoch 00460: val_loss did not improve from 0.53321
#
# Epoch 00461: val_loss did not improve from 0.53321
#
# Epoch 00462: val_loss did not improve from 0.53321
#
# Epoch 00463: val_loss did not improve from 0.53321
#
# Epoch 00464: val_loss did not improve from 0.53321
#
# Epoch 00465: val_loss did not improve from 0.53321
#
# Epoch 00466: val_loss did not improve from 0.53321
#
# Epoch 00467: val_loss did not improve from 0.53321
#
# Epoch 00468: val_loss did not improve from 0.53321
# Epoch 00469: val_loss did not improve from 0.53321
#
# Epoch 00470: val_loss did not improve from 0.53321
#
# Epoch 00471: val_loss did not improve from 0.53321
#
# Epoch 00472: val_loss did not improve from 0.53321
#
# Epoch 00473: val_loss did not improve from 0.53321
#
# Epoch 00474: val_loss did not improve from 0.53321
#
# Epoch 00475: val_loss did not improve from 0.53321
#
# Epoch 00476: val_loss did not improve from 0.53321
#
# Epoch 00477: val_loss did not improve from 0.53321
#
# Epoch 00478: val_loss did not improve from 0.53321
#
# Epoch 00479: val_loss did not improve from 0.53321
#
# Epoch 00480: val_loss did not improve from 0.53321
#
# Epoch 00481: val_loss did not improve from 0.53321
#
# Epoch 00482: val_loss did not improve from 0.53321
#
# Epoch 00483: val_loss did not improve from 0.53321
#
# Epoch 00484: val_loss did not improve from 0.53321
#
# Epoch 00485: val_loss did not improve from 0.53321
#
# Epoch 00486: val_loss did not improve from 0.53321
#
# Epoch 00487: val_loss did not improve from 0.53321
#
# Epoch 00488: val_loss did not improve from 0.53321
#
# Epoch 00489: val_loss did not improve from 0.53321
#
# Epoch 00490: val_loss did not improve from 0.53321
#
# Epoch 00491: val_loss did not improve from 0.53321
#
# Epoch 00492: val_loss did not improve from 0.53321
#
# Epoch 00493: val_loss did not improve from 0.53321
#
# Epoch 00494: val_loss did not improve from 0.53321
#
# Epoch 00495: val_loss did not improve from 0.53321
#
# Epoch 00496: val_loss did not improve from 0.53321
#
# Epoch 00497: val_loss did not improve from 0.53321
#
# Epoch 00498: val_loss did not improve from 0.53321
#
# Epoch 00499: val_loss did not improve from 0.53321
#
# Epoch 00500: val_loss did not improve from 0.53321
#
# Epoch 00501: val_loss did not improve from 0.53321
#
# Epoch 00502: val_loss did not improve from 0.53321
#
# Epoch 00503: val_loss did not improve from 0.53321
#
# Epoch 00504: val_loss did not improve from 0.53321
#
# Epoch 00505: val_loss did not improve from 0.53321
#
# Epoch 00506: val_loss did not improve from 0.53321
#
# Epoch 00507: val_loss did not improve from 0.53321
#
# Epoch 00508: val_loss did not improve from 0.53321
#
# Epoch 00509: val_loss did not improve from 0.53321
#
# Epoch 00510: val_loss did not improve from 0.53321
#
# Epoch 00511: val_loss did not improve from 0.53321
#
# Epoch 00512: val_loss did not improve from 0.53321
#
# Epoch 00513: val_loss did not improve from 0.53321
#
# Epoch 00514: val_loss did not improve from 0.53321
#
# Epoch 00515: val_loss did not improve from 0.53321
#
# Epoch 00516: val_loss did not improve from 0.53321
#
# Epoch 00517: val_loss did not improve from 0.53321
#
# Epoch 00518: val_loss did not improve from 0.53321
#
# Epoch 00519: val_loss did not improve from 0.53321
#
# Epoch 00520: val_loss did not improve from 0.53321
#
# Epoch 00521: val_loss did not improve from 0.53321
#
# Epoch 00522: val_loss did not improve from 0.53321
#
# Epoch 00523: val_loss did not improve from 0.53321
#
# Epoch 00524: val_loss did not improve from 0.53321
#
# Epoch 00525: val_loss did not improve from 0.53321
#
# Epoch 00526: val_loss did not improve from 0.53321
#
# Epoch 00527: val_loss did not improve from 0.53321
#
# Epoch 00528: val_loss did not improve from 0.53321
#
# Epoch 00529: val_loss did not improve from 0.53321
#
# Epoch 00530: val_loss did not improve from 0.53321
#
# Epoch 00531: val_loss did not improve from 0.53321
#
# Epoch 00532: val_loss did not improve from 0.53321

# %%
_, train_acc = saved_model.evaluate(train_features, train_target, verbose=0)
_, test_acc = saved_model.evaluate(test_features, test_target, verbose=0)

print('Train Accuracy: %.3f, Test Accuracy: %.3f' % (train_acc, test_acc))
# Out:
# Train Accuracy: 0.741, Test Accuracy: 0.747

# %%
plt.subplots(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.title('Loss after each Epoch')
plt.plot(history.epoch[::10], history.history['loss'][::10], label='Train')
plt.plot(history.epoch[::10], history.history['val_loss'][::10], label='Test')
plt.legend(['Train', 'Test'],loc='upper right', title='Sample', facecolor='white',fancybox=True)
plt.xlabel('Loss')
plt.ylabel('Epochs')
plt.savefig('data/results/loss_acc.jpg', quality=100)
# Out:
# <ipython-input-64-902fe9cdc023>:9: MatplotlibDeprecationWarning:
# The 'quality' parameter of print_jpg() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use pil_kwargs={'quality': ...} instead. If any parameter follows 'quality', they should be passed as keyword, not positionally.
#   plt.savefig('data/results/loss_acc.jpg', quality=100)

# %%
df_2022 = pd.read_csv('data/French_open_2022.csv')
df_raw = pd.read_csv('data/combined_raw_data.csv')

df_2022['Date'] = '2022/05/29'
df_2022['Surface'] = 'Clay'
df_2022['diff_rank'] = df_2022['player_0_rank'] - df_2022['player_1_rank']
# Out:
# C:\Users\akhil\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (33) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
from datetime import datetime
from datetime import timedelta

# %%
def get_player_1_name(winner_name, winner_rank, loser_name, loser_rank):
   
    if winner_rank < loser_rank:
        return winner_name
    else:
        return loser_name

# %%
def get_player_1_rank(winner_rank, loser_rank):
    
    if winner_rank < loser_rank:
        return winner_rank
    else:
        return loser_rank

# %%
def get_player_2_name(winner_name, winner_rank, loser_name, loser_rank):
   
    if winner_rank > loser_rank:
        return winner_name
    else:
        return loser_name

# %%
def get_player_2_rank(winner_rank, loser_rank):
    
    if winner_rank > loser_rank:
        return winner_rank
    else:
        return loser_rank

# %%
def outcome(winner_rank, loser_rank):
   
    if winner_rank< loser_rank:
        return 0
    else:
        return 1

# %%
def get_player_1_odd(winner_odd, winner_rank, loser_odd, loser_rank):
   
    if winner_rank < loser_rank:
        return winner_odd
    else:
        return loser_odd

# %%
def get_player_2_odd(winner_odd, winner_rank, loser_odd, loser_rank):
   
    if winner_rank > loser_rank:
        return winner_odd
    else:
        return loser_odd

# %%
def subtract_days(date_string, num_days):
    
    date_temp = (datetime.strptime(date_string, '%Y/%m/%d') - timedelta(days=num_days))
    return date_temp.strftime("%Y/%m/%d")

# %%
def winning_percentage(player_id, data,  type1='matches', current_date=None, surface='All', last_n_weeks=0):
    """
    Caculate different player stats
    :param player_id: Name or ID of Player
    :param data: The raw dataframe from http://www.tennis-data.co.uk/alldata.php
    :param type1: Options: ['matches', 'total_matches', 'games', 'matches_5_sets', 'win_or_close_sets']
    :param current_date: Date of match
    :param surface: Surface options: ['All', 'Grass', 'Hard', 'Clay']
    :param last_n_weeks: Get stats from the past n weeks
    :return: Returns the players Stat for the specified parameters.
    """
    data = data[data['Date'] < current_date]

    if surface!='All':
        data = data[data['Surface'] == surface]

    if last_n_weeks>0:
        last_date = subtract_days(current_date, (last_n_weeks * 7))
        data = data[data['Date'] >= last_date]

    if type1 == 'matches':
        wins = (data['Winner'] == player_id).sum()
        loses = (data['Loser'] == player_id).sum()

    elif type1 == 'total_matches':
        return (data['Winner'] == player_id).sum() + (data['Loser'] == player_id).sum()


    elif type1 == 'matches_5_sets':
        wins = ((data['Winner'] == player_id) & (data['best_of_5'] == 1)).sum()
        loses = ((data['Loser'] == player_id) & (data['best_of_5'] == 1)).sum()


    elif type1 == 'games':
        winner_set_list = ['W1', 'W2', 'W3', 'W4', 'W5']
        loser_set_list = ['L1', 'L2', 'L3', 'L4', 'L5']

        wins = data[data['Winner'] == player_id][winner_set_list].values.sum() + data[data['Loser'] == player_id][loser_set_list].values.sum()
        loses = data[data['Loser'] == player_id][winner_set_list].values.sum() + data[data['Winner'] == player_id][loser_set_list].values.sum()


    elif type1 == 'win_or_close_sets':

        wins = 0
        loses = 0

        data_3_set = data[data['best_of_5'] == 0]
        data_5_set = data[data['best_of_5'] == 1]

        for i in range(1, 4):
            wins = wins + ((data_3_set['Winner'] == player_id) & (data_3_set[('W' + str(i))] >= 5)).sum()
            wins = wins + ((data_3_set['Loser'] == player_id) & (data_3_set[('L' + str(i))] >= 5)).sum()
            loses = loses + ((data_3_set['Winner'] == player_id) & (data_3_set[('W' + str(i))] < 5)).sum()
            loses = loses + ((data_3_set['Loser'] == player_id) & (data_3_set[('L' + str(i))] < 5)).sum()

        for i in range(1, 6):
            wins = wins + ((data_5_set['Winner'] == player_id) & (data_5_set[('W' + str(i))] >= 5)).sum()
            wins = wins + ((data_5_set['Loser'] == player_id) & (data_5_set[('L' + str(i))] >= 5)).sum()
            loses = loses + ((data_5_set['Winner'] == player_id) & (data_5_set[('W' + str(i))] < 5)).sum()
            loses = loses + ((data_5_set['Loser'] == player_id) & (data_5_set[('L' + str(i))] < 5)).sum()

    total = wins + loses

    if total <2:
        win_percent = 0

    else:
        win_percent = wins / total
    return win_percent

# %%
def winning_percent_hh(player_name, opponent_name, data, type1='matches', current_date=None, surface='All', last_n_weeks=0):
    
    data = data[data['Date'] < current_date]

    if surface!='All':
        data = data[data['Surface'] == surface]

    if last_n_weeks>0:
        last_date = subtract_days(current_date, (last_n_weeks * 7))
        data = data[data['Date'] >= last_date]

    if type1 == 'matches':
        wins = ((data['Winner'] == player_name) & (data['Loser'] == opponent_name)).sum()
        loses = ((data['Winner'] == opponent_name) & (data['Loser'] == player_name)).sum()

    elif type1 == 'games':
        winner_set_list = ['W1', 'W2', 'W3', 'W4', 'W5']
        loser_set_list = ['L1', 'L2', 'L3', 'L4', 'L5']

        wins = data[(data['Winner'] == player_name) & (data['Loser'] == opponent_name)][winner_set_list].values.sum() + \
               data[(data['Winner'] == opponent_name) & (data['Loser'] == player_name)][loser_set_list].values.sum()

        loses = data[(data['Winner'] == opponent_name) & (data['Loser'] == player_name)][winner_set_list].values.sum() + \
                data[(data['Winner'] == player_name) & (data['Loser'] == opponent_name)][loser_set_list].values.sum()

    total = wins + loses

    if total == 0:
        win_percent = 0

    else:
        win_percent = wins / total
    return win_percent

# %%
def create_features(df_combined, df):
    

   
    print('Creating Player Career Stats All Surface')

    df_combined.loc[:, 'player_0_match_win_percent'] = df_combined.apply(
        lambda row: winning_percentage(row['player_0'], df, type1='matches', current_date=row['Date'], last_n_weeks=0),
        axis=1)
    df_combined.loc[:, 'player_1_match_win_percent'] = df_combined.apply(
        lambda row: winning_percentage(row['player_1'], df, type1='matches', current_date=row['Date'], last_n_weeks=0),
        axis=1)

    df_combined.loc[:, 'player_0_games_win_percent'] = df_combined.apply(
        lambda row: winning_percentage(row['player_0'], df, type1='games', current_date=row['Date'], last_n_weeks=0),
        axis=1)
    df_combined.loc[:, 'player_1_games_win_percent'] = df_combined.apply(
        lambda row: winning_percentage(row['player_1'], df, type1='games', current_date=row['Date'], last_n_weeks=0),
        axis=1)

    df_combined.loc[:, 'player_0_5_set_match_win_percent'] = df_combined.apply(
        lambda row: winning_percentage(row['player_0'], df, type1='matches_5_sets', current_date=row['Date'],
                                       last_n_weeks=0), axis=1)
    df_combined.loc[:, 'player_1_5_set_match_win_percent'] = df_combined.apply(
        lambda row: winning_percentage(row['player_1'], df, type1='matches_5_sets', current_date=row['Date'],
                                       last_n_weeks=0), axis=1)

    df_combined.loc[:, 'player_0_close_sets_percent'] = df_combined.apply(
        lambda row: winning_percentage(row['player_0'], df, type1='win_or_close_sets', current_date=row['Date'],
                                       last_n_weeks=0), axis=1)
    df_combined.loc[:, 'player_1_close_sets_percent'] = df_combined.apply(
        lambda row: winning_percentage(row['player_1'], df, type1='win_or_close_sets', current_date=row['Date'],
                                       last_n_weeks=0), axis=1)

    

    print('Creating Player Career Stats on Clay')

    df_combined.loc[:, 'player_0_match_win_percent_clay'] = df_combined.apply(
        lambda row: winning_percentage(row['player_0'], df, type1='matches', current_date=row['Date'],
                                       surface=row['Surface'], last_n_weeks=0), axis=1)
    df_combined.loc[:, 'player_1_match_win_percent_clay'] = df_combined.apply(
        lambda row: winning_percentage(row['player_1'], df, type1='matches', current_date=row['Date'],
                                       surface=row['Surface'], last_n_weeks=0), axis=1)

    df_combined.loc[:, 'player_0_games_win_percent_clay'] = df_combined.apply(
        lambda row: winning_percentage(row['player_0'], df, type1='games', current_date=row['Date'],
                                       surface=row['Surface'], last_n_weeks=0), axis=1)
    df_combined.loc[:, 'player_1_games_win_percent_clay'] = df_combined.apply(
        lambda row: winning_percentage(row['player_1'], df, type1='games', current_date=row['Date'],
                                       surface=row['Surface'], last_n_weeks=0), axis=1)

    df_combined.loc[:, 'player_0_5_set_match_win_percent_clay'] = df_combined.apply(
        lambda row: winning_percentage(row['player_0'], df, type1='matches_5_sets', current_date=row['Date'],
                                       surface=row['Surface'], last_n_weeks=0), axis=1)
    df_combined.loc[:, 'player_1_5_set_match_win_percent_clay'] = df_combined.apply(
        lambda row: winning_percentage(row['player_1'], df, type1='matches_5_sets', current_date=row['Date'],
                                       surface=row['Surface'], last_n_weeks=0), axis=1)

    df_combined.loc[:, 'player_0_close_sets_percent_clay'] = df_combined.apply(
        lambda row: winning_percentage(row['player_0'], df, type1='win_or_close_sets', current_date=row['Date'],
                                       surface=row['Surface'], last_n_weeks=0), axis=1)
    df_combined.loc[:, 'player_1_close_sets_percent_clay'] = df_combined.apply(
        lambda row: winning_percentage(row['player_1'], df, type1='win_or_close_sets', current_date=row['Date'],
                                       surface=row['Surface'], last_n_weeks=0), axis=1)

  

    print('Creating Player Career Stats All Surface Last 52 Weeks')

    df_combined.loc[:, 'player_0_match_win_percent_52'] = df_combined.apply(
        lambda row: winning_percentage(row['player_0'], df, type1='matches', current_date=row['Date'], last_n_weeks=52),
        axis=1)
    df_combined.loc[:, 'player_1_match_win_percent_52'] = df_combined.apply(
        lambda row: winning_percentage(row['player_1'], df, type1='matches', current_date=row['Date'], last_n_weeks=52),
        axis=1)

    df_combined.loc[:, 'player_0_games_win_percent_52'] = df_combined.apply(
        lambda row: winning_percentage(row['player_0'], df, type1='games', current_date=row['Date'], last_n_weeks=52),
        axis=1)
    df_combined.loc[:, 'player_1_games_win_percent_52'] = df_combined.apply(
        lambda row: winning_percentage(row['player_1'], df, type1='games', current_date=row['Date'], last_n_weeks=52),
        axis=1)

    df_combined.loc[:, 'player_0_5_set_match_win_percent_52'] = df_combined.apply(
        lambda row: winning_percentage(row['player_0'], df, type1='matches_5_sets', current_date=row['Date'],
                                       last_n_weeks=52), axis=1)
    df_combined.loc[:, 'player_1_5_set_match_win_percent_52'] = df_combined.apply(
        lambda row: winning_percentage(row['player_1'], df, type1='matches_5_sets', current_date=row['Date'],
                                       last_n_weeks=52), axis=1)

    df_combined.loc[:, 'player_0_close_sets_percent_52'] = df_combined.apply(
        lambda row: winning_percentage(row['player_0'], df, type1='win_or_close_sets', current_date=row['Date'],
                                       last_n_weeks=52), axis=1)
    df_combined.loc[:, 'player_1_close_sets_percent_52'] = df_combined.apply(
        lambda row: winning_percentage(row['player_1'], df, type1='win_or_close_sets', current_date=row['Date'],
                                       last_n_weeks=52), axis=1)

    

    print('Creating Player Career Stats on Clay Last 60 Weeks')

    df_combined.loc[:, 'player_0_match_win_percent_clay_60'] = df_combined.apply(
        lambda row: winning_percentage(row['player_0'], df, type1='matches', current_date=row['Date'],
                                       surface=row['Surface'], last_n_weeks=60), axis=1)
    df_combined.loc[:, 'player_1_match_win_percent_clay_60'] = df_combined.apply(
        lambda row: winning_percentage(row['player_1'], df, type1='matches', current_date=row['Date'],
                                       surface=row['Surface'], last_n_weeks=60), axis=1)

    df_combined.loc[:, 'player_0_games_win_percent_clay_60'] = df_combined.apply(
        lambda row: winning_percentage(row['player_0'], df, type1='games', current_date=row['Date'],
                                       surface=row['Surface'], last_n_weeks=60), axis=1)
    df_combined.loc[:, 'player_1_games_win_percent_clay_60'] = df_combined.apply(
        lambda row: winning_percentage(row['player_1'], df, type1='games', current_date=row['Date'],
                                       surface=row['Surface'], last_n_weeks=60), axis=1)

    df_combined.loc[:, 'player_0_5_set_match_win_percent_clay_60'] = df_combined.apply(
        lambda row: winning_percentage(row['player_0'], df, type1='matches_5_sets', current_date=row['Date'],
                                       surface=row['Surface'], last_n_weeks=60), axis=1)
    df_combined.loc[:, 'player_1_5_set_match_win_percent_clay_60'] = df_combined.apply(
        lambda row: winning_percentage(row['player_1'], df, type1='matches_5_sets', current_date=row['Date'],
                                       surface=row['Surface'], last_n_weeks=60), axis=1)

    df_combined.loc[:, 'player_0_close_sets_percent_clay_60'] = df_combined.apply(
        lambda row: winning_percentage(row['player_0'], df, type1='win_or_close_sets', current_date=row['Date'],
                                       surface=row['Surface'], last_n_weeks=60), axis=1)
    df_combined.loc[:, 'player_1_close_sets_percent_clay_60'] = df_combined.apply(
        lambda row: winning_percentage(row['player_1'], df, type1='win_or_close_sets', current_date=row['Date'],
                                       surface=row['Surface'], last_n_weeks=60), axis=1)

   

    print('Creating Player Head to Head Career Stats All Surface')

    df_combined.loc[:, 'player_0_match_win_percent_hh'] = df_combined.apply(
        lambda row: winning_percent_hh(row['player_0'], row['player_1'], df, type1='matches', current_date=row['Date'],
                                       last_n_weeks=0), axis=1)
    df_combined.loc[:, 'player_1_match_win_percent_hh'] = df_combined.apply(
        lambda row: winning_percent_hh(row['player_1'], row['player_0'], df, type1='matches', current_date=row['Date'],
                                       last_n_weeks=0), axis=1)

    df_combined.loc[:, 'player_0_games_win_percent_hh'] = df_combined.apply(
        lambda row: winning_percent_hh(row['player_0'], row['player_1'], df, type1='games', current_date=row['Date'],
                                       last_n_weeks=0), axis=1)
    df_combined.loc[:, 'player_1_games_win_percent_hh'] = df_combined.apply(
        lambda row: winning_percent_hh(row['player_1'], row['player_0'], df, type1='games', current_date=row['Date'],
                                       last_n_weeks=0), axis=1)

   

    print('Creating Player Head to Head Career Stats On Clay')

    df_combined.loc[:, 'player_0_match_win_percent_clay_hh'] = df_combined.apply(
        lambda row: winning_percent_hh(row['player_0'], row['player_1'], df, type1='matches', current_date=row['Date'],
                                       last_n_weeks=0), axis=1)
    df_combined.loc[:, 'player_1_match_win_percent_clay_hh'] = df_combined.apply(
        lambda row: winning_percent_hh(row['player_1'], row['player_0'], df, type1='matches', current_date=row['Date'],
                                       last_n_weeks=0), axis=1)

    df_combined.loc[:, 'player_0_games_win_percent_clay_hh'] = df_combined.apply(
        lambda row: winning_percent_hh(row['player_0'], row['player_1'], df, type1='games', current_date=row['Date'],
                                       last_n_weeks=0), axis=1)
    df_combined.loc[:, 'player_1_games_win_percent_clay_hh'] = df_combined.apply(
        lambda row: winning_percent_hh(row['player_1'], row['player_0'], df, type1='games', current_date=row['Date'],
                                       last_n_weeks=0), axis=1)

   

    print('Creating Difference Variables')

    df_combined.loc[:, 'diff_match_win_percent'] = df_combined['player_0_match_win_percent'] - df_combined[
        'player_1_match_win_percent']
    df_combined.loc[:, 'diff_games_win_percent'] = df_combined['player_0_games_win_percent'] - df_combined[
        'player_1_games_win_percent']
    df_combined.loc[:, 'diff_5_set_match_win_percent'] = df_combined['player_0_5_set_match_win_percent'] - df_combined[
        'player_1_5_set_match_win_percent']
    df_combined.loc[:, 'diff_close_sets_percent'] = df_combined['player_0_close_sets_percent'] - df_combined[
        'player_1_close_sets_percent']

    df_combined.loc[:, 'diff_match_win_percent_clay'] = df_combined['player_0_match_win_percent_clay'] - df_combined[
        'player_1_match_win_percent_clay']
    df_combined.loc[:, 'diff_games_win_percent_clay'] = df_combined['player_0_games_win_percent_clay'] - df_combined[
        'player_1_games_win_percent_clay']
    df_combined.loc[:, 'diff_5_set_match_win_percent_clay'] = df_combined['player_0_5_set_match_win_percent_clay'] - \
                                                               df_combined['player_1_5_set_match_win_percent_clay']
    df_combined.loc[:, 'diff_close_sets_percent_clay'] = df_combined['player_0_close_sets_percent_clay'] - \
                                                          df_combined['player_1_close_sets_percent_clay']

    df_combined.loc[:, 'diff_match_win_percent_52'] = df_combined['player_0_match_win_percent_52'] - df_combined[
        'player_1_match_win_percent_52']
    df_combined.loc[:, 'diff_games_win_percent_52'] = df_combined['player_0_games_win_percent_52'] - df_combined[
        'player_1_games_win_percent_52']
    df_combined.loc[:, 'diff_5_set_match_win_percent_52'] = df_combined['player_0_5_set_match_win_percent_52'] - \
                                                            df_combined['player_1_5_set_match_win_percent_52']
    df_combined.loc[:, 'diff_close_sets_percent_52'] = df_combined['player_0_close_sets_percent_52'] - df_combined[
        'player_1_close_sets_percent_52']

    df_combined.loc[:, 'diff_match_win_percent_clay_60'] = df_combined['player_0_match_win_percent_clay_60'] - \
                                                            df_combined['player_1_match_win_percent_clay_60']
    df_combined.loc[:, 'diff_games_win_percent_clay_60'] = df_combined['player_0_games_win_percent_clay_60'] - \
                                                            df_combined['player_1_games_win_percent_clay_60']
    df_combined.loc[:, 'diff_5_set_match_win_percent_clay_60'] = df_combined[
                                                                      'player_0_5_set_match_win_percent_clay_60'] - \
                                                                  df_combined[
                                                                      'player_1_5_set_match_win_percent_clay_60']
    df_combined.loc[:, 'diff_close_sets_percent_clay_60'] = df_combined['player_0_close_sets_percent_clay_60'] - \
                                                             df_combined['player_1_close_sets_percent_clay_60']

    df_combined.loc[:, 'diff_match_win_percent_hh'] = df_combined['player_0_match_win_percent_hh'] - df_combined[
        'player_1_match_win_percent_hh']
    df_combined.loc[:, 'diff_games_win_percent_hh'] = df_combined['player_0_games_win_percent_hh'] - df_combined[
        'player_1_games_win_percent_hh']

    df_combined.loc[:, 'diff_match_win_percent_clay_hh'] = df_combined['player_0_match_win_percent_clay_hh'] - \
                                                            df_combined['player_1_match_win_percent_clay_hh']
    df_combined.loc[:, 'diff_games_win_percent_clay_hh'] = df_combined['player_0_games_win_percent_clay_hh'] - \
                                                            df_combined['player_1_games_win_percent_clay_hh']

    return df_combined

# %%
df_2022 = create_features(df_2022, df_raw)
# Out:
# Creating Player Career Stats All Surface
# Creating Player Career Stats on Clay
# Creating Player Career Stats All Surface Last 52 Weeks
# Creating Player Career Stats on Clay Last 60 Weeks
# Creating Player Head to Head Career Stats All Surface
# Creating Player Head to Head Career Stats On Clay
# Creating Difference Variables

# %%
features_16 = df_2022[features_list]

predict_x = saved_model.predict(features_16)
df_2022['prediction'] = np.argmax(predict_x,axis=1)
df_2022['probability'] = 1 - np.abs(df_2022.prediction - saved_model.predict(features_16).flatten())
df_2022[['Round', 'player_0', 'player_1', 'prediction', 'probability']]
# Out:
#           Round     player_0            player_1  prediction  probability
# 0   Round of 16  Djokovic N.      Schwartzman D.           0     0.846453
# 1   Round of 16    Zverev A.  Zapata Miralles B.           0     0.896967
# 2   Round of 16     Nadal R.  Auger-Aliassime F.           0     0.881026
# 3   Round of 16   Alcaraz C.        Khachanov K.           0     0.728728
# 4   Round of 16      Ruud C.          Hurkacz H.           0     0.765664
# 5   Round of 16      Rune H.        Tsitsipas S.           0     0.002067
# 6   Round of 16    Rublev A.           Sinner J.           0     0.411373
# 7   Round of 16     Cilic M.         Medvedev D.           0     0.064217
# 8       Quarter    Zverev A.          Alcaraz C.           0     0.484966
# 9       Quarter     Nadal R.         Djokovic N.           0     0.374757
# 10      Quarter     Cilic M.           Rublev A.           0     0.070842
# 11      Quarter      Ruud C.             Rune H.           0     0.901055
# 12        Semis     Nadal R.           Zverev A.           0     0.470418
# 13        Semis      Ruud C.            Cilic M.           0     0.774374
# 14       Finals     Nadal R.             Ruud C.           0     0.700099
